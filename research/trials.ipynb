# %%
import gdown

# %%
url="https://drive.google.com/file/d/1Eki5CjSxr1Su13d3Pd368s227wWSqjUq/view?usp=drive_link"

# %%
file_id = url.split("/d/")[1].split("/")[0]
file_id
# Out:
# '1Eki5CjSxr1Su13d3Pd368s227wWSqjUq'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Eki5CjSxr1Su13d3Pd368s227wWSqjUq
# From (redirected): https://drive.google.com/uc?id=1Eki5CjSxr1Su13d3Pd368s227wWSqjUq&confirm=t&uuid=cadf0870-59a8-42b0-b834-6d20dca2bda6
# To: c:\ALI\Kidney-Disease-Classification-Deep-Learning-Project\research\kidney-CT-Scan-data.zip
# 100%|██████████| 57.7M/57.7M [00:05<00:00, 9.85MB/s]
# 'kidney-CT-Scan-data.zip'
